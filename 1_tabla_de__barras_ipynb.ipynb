# %% [markdown]
# <a href="https://colab.research.google.com/github/moshi516/summercamppruebapython/blob/main/1_tabla_de__barras_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sqlite3
import seaborn as sns
import matplotlib.pyplot as plt
conexion = sqlite3.connect("torneo_smash.db")
df_original = pd.read_csv("smash_dataset_clean.csv", encoding="latin1")
df_original.to_sql("combates", conexion, if_exists="replace", index=False)

consulta_sql = """

SELECT Nombre,Sexo,Edad,Personaje

FROM combates

ORDER BY nombre ASC """

df_filtrado = pd.read_sql_query(consulta_sql, conexion)

df_filtrado.head(24) # head(24) muestra los 24 personas en orden de  DESC
# Out:
#         Nombre    Sexo  Edad        Personaje
# 0       Adrian  Hombre    13       Incineroar
# 1          Ale  Hombre    13            Kirby
# 2         Ana    Mujer    14         Inkgling
# 3       Andres  Hombre    13              R0B
# 4       Andres  Hombre    13            Samus
# 5       Carlos  Hombre    16  Game and watch
# 6       Carlos  Hombre    16   Game and watch
# 7       Daniel  Hombre    13       Metaknight
# 8         Fred  Hombre    21      Donkey Kong
# 9         Fred  Hombre    21      Donkey Kong
# 10     Gabriel  Hombre    15       Little mac
# 11     Gabriel  Hombre    15       Little mac
# 12    Jonathan  Hombre    19            Kirby
# 13       Josue  Hombre    19            Kirby
# 14      Julian  Hombre    13            Daisy
# 15     Kuciana   Mujer    14            Sonic
# 16      Laura    Mujer    16            Kirby
# 17    Leonardo  Hombre    13            shulk
# 18     Marilyn   Mujer    14          Rosalia
# ...

# %%
sns.set_theme(style="darkgrid")

plt.figure(figsize=(16, 8))

grafico_barras = sns.barplot(
    data=df_filtrado,
    x="Nombre",
    y="Personaje",
    palette="magma",

    errorbar=None
)
plt.title("🥊 Nombres y personaje", fontsize=16, fontweight="bold", pad=15)
plt.xlabel("Nombre de partcipantes", fontsize=12, labelpad=10)
plt.ylabel("Personajes", fontsize=12, labelpad=10)

plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_19835/1846630818.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   grafico_barras = sns.barplot(
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129354 (\N{BOXING GLOVE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
