# %% [markdown]
# <a href="https://colab.research.google.com/github/moshi516/summercamppruebapython/blob/main/pruebapython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("summer")
# Out:
# summer

# %%
jugador = "zonic"
print(jugador,"Ha entrado a la Arena")
jugador2 = "Kirby"
print(jugador2, "se ha caido del escenario")
# Out:
# zonic Ha entrado a la Arena
# Kirby se ha caido del escenario
